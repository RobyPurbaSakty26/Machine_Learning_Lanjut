# %%
import pandas as pd
df = pd.read_csv('yelp_labelled.txt', names=['sentence', 'label'], sep='\t')

# %%
df.tail()
# Out:
#                                               sentence  label
# 995  I think food should have flavor and texture an...      0
# 996                           Appetite instantly gone.      0
# 997  Overall I was not impressed and would not go b...      0
# 998  The whole experience was underwhelming, and I ...      0
# 999  Then, as if I hadn't wasted enough of my life ...      0

# %%
from sklearn.model_selection import train_test_split
kalimat = df['sentence'].values
y = df['label'].values
kalimat_latih, kalimat_test, y_latih, y_test = train_test_split(kalimat, y, test_size=0.2)

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
 
tokenizer = Tokenizer(num_words=250, oov_token='x')
tokenizer.fit_on_texts(kalimat_latih) 
tokenizer.fit_on_texts(kalimat_test)
 
sekuens_latih = tokenizer.texts_to_sequences(kalimat_latih)
sekuens_test = tokenizer.texts_to_sequences(kalimat_test)
 
padded_latih = pad_sequences(sekuens_latih, maxlen=20) 
padded_test = pad_sequences(sekuens_test, maxlen=20)
print(padded_latih)
# Out:
# [[  1  38  10 ...   6  17 152]
#  [  0   0   0 ...  18   3  12]
#  [  0   0   0 ... 202  28   1]
#  ...
#  [  0  51  33 ...  16  14  33]
#  [  1   1  31 ...   2  12   1]
#  [  0   0   0 ...   8  55   1]]

# %%
import tensorflow as tf
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(250, 16, input_length=20),
    # tf.keras.layers.LSTM(64),
    tf.keras.layers.GlobalAveragePooling1D(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
num_epochs = 100
history = model.fit(padded_latih, y_latih, epochs=num_epochs, 
                    validation_data=(padded_test, y_test), verbose=2)
# Out:
# Epoch 1/100
# 25/25 - 1s - loss: 0.6930 - accuracy: 0.4988 - val_loss: 0.6928 - val_accuracy: 0.5150 - 1s/epoch - 51ms/step
# Epoch 2/100
# 25/25 - 0s - loss: 0.6905 - accuracy: 0.5387 - val_loss: 0.6920 - val_accuracy: 0.5350 - 146ms/epoch - 6ms/step
# Epoch 3/100
# 25/25 - 0s - loss: 0.6852 - accuracy: 0.5800 - val_loss: 0.6873 - val_accuracy: 0.5350 - 147ms/epoch - 6ms/step
# Epoch 4/100
# 25/25 - 0s - loss: 0.6737 - accuracy: 0.6150 - val_loss: 0.6778 - val_accuracy: 0.5650 - 127ms/epoch - 5ms/step
# Epoch 5/100
# 25/25 - 0s - loss: 0.6518 - accuracy: 0.6737 - val_loss: 0.6617 - val_accuracy: 0.5750 - 121ms/epoch - 5ms/step
# Epoch 6/100
# 25/25 - 0s - loss: 0.6157 - accuracy: 0.7025 - val_loss: 0.6318 - val_accuracy: 0.6600 - 152ms/epoch - 6ms/step
# Epoch 7/100
# 25/25 - 0s - loss: 0.5620 - accuracy: 0.7638 - val_loss: 0.6027 - val_accuracy: 0.6850 - 218ms/epoch - 9ms/step
# Epoch 8/100
# 25/25 - 0s - loss: 0.5003 - accuracy: 0.7962 - val_loss: 0.5748 - val_accuracy: 0.6950 - 330ms/epoch - 13ms/step
# Epoch 9/100
# 25/25 - 0s - loss: 0.4459 - accuracy: 0.8125 - val_loss: 0.5547 - val_accuracy: 0.7100 - 266ms/epoch - 11ms/step
# Epoch 10/100
# 25/25 - 0s - loss: 0.4031 - accuracy: 0.8338 - val_loss: 0.5486 - val_accuracy: 0.7050 - 115ms/epoch - 5ms/step
# Epoch 11/100
# 25/25 - 0s - loss: 0.3660 - accuracy: 0.8537 - val_loss: 0.5426 - val_accuracy: 0.7400 - 127ms/epoch - 5ms/step
# Epoch 12/100
# 25/25 - 0s - loss: 0.3396 - accuracy: 0.8675 - val_loss: 0.5528 - val_accuracy: 0.7300 - 124ms/epoch - 5ms/step
# Epoch 13/100
# 25/25 - 0s - loss: 0.3189 - accuracy: 0.8725 - val_loss: 0.5512 - val_accuracy: 0.7550 - 127ms/epoch - 5ms/step
# Epoch 14/100
# 25/25 - 0s - loss: 0.3042 - accuracy: 0.8650 - val_loss: 0.5579 - val_accuracy: 0.7500 - 121ms/epoch - 5ms/step
# Epoch 15/100
# 25/25 - 0s - loss: 0.2926 - accuracy: 0.8712 - val_loss: 0.5625 - val_accuracy: 0.7600 - 126ms/epoch - 5ms/step
# Epoch 16/100
# 25/25 - 0s - loss: 0.2894 - accuracy: 0.8725 - val_loss: 0.5750 - val_accuracy: 0.7450 - 118ms/epoch - 5ms/step
# Epoch 17/100
# 25/25 - 0s - loss: 0.2742 - accuracy: 0.8850 - val_loss: 0.5824 - val_accuracy: 0.7550 - 113ms/epoch - 5ms/step
# Epoch 18/100
# 25/25 - 0s - loss: 0.2656 - accuracy: 0.8825 - val_loss: 0.6292 - val_accuracy: 0.7050 - 112ms/epoch - 4ms/step
# Epoch 19/100
# 25/25 - 0s - loss: 0.2643 - accuracy: 0.8963 - val_loss: 0.6248 - val_accuracy: 0.7200 - 136ms/epoch - 5ms/step
# Epoch 20/100
# 25/25 - 0s - loss: 0.2551 - accuracy: 0.8963 - val_loss: 0.6110 - val_accuracy: 0.7500 - 128ms/epoch - 5ms/step
# Epoch 21/100
# 25/25 - 0s - loss: 0.2498 - accuracy: 0.8925 - val_loss: 0.6367 - val_accuracy: 0.7100 - 156ms/epoch - 6ms/step
# Epoch 22/100
# 25/25 - 0s - loss: 0.2461 - accuracy: 0.8863 - val_loss: 0.6361 - val_accuracy: 0.7300 - 115ms/epoch - 5ms/step
# Epoch 23/100
# 25/25 - 0s - loss: 0.2411 - accuracy: 0.8988 - val_loss: 0.6555 - val_accuracy: 0.7150 - 115ms/epoch - 5ms/step
# Epoch 24/100
# 25/25 - 0s - loss: 0.2421 - accuracy: 0.8950 - val_loss: 0.6570 - val_accuracy: 0.7400 - 111ms/epoch - 4ms/step
# Epoch 25/100
# 25/25 - 0s - loss: 0.2363 - accuracy: 0.8950 - val_loss: 0.6707 - val_accuracy: 0.7300 - 114ms/epoch - 5ms/step
# Epoch 26/100
# 25/25 - 0s - loss: 0.2311 - accuracy: 0.8900 - val_loss: 0.6614 - val_accuracy: 0.7550 - 116ms/epoch - 5ms/step
# Epoch 27/100
# 25/25 - 0s - loss: 0.2302 - accuracy: 0.8988 - val_loss: 0.6808 - val_accuracy: 0.7400 - 116ms/epoch - 5ms/step
# Epoch 28/100
# 25/25 - 0s - loss: 0.2295 - accuracy: 0.9013 - val_loss: 0.7406 - val_accuracy: 0.7250 - 120ms/epoch - 5ms/step
# Epoch 29/100
# 25/25 - 0s - loss: 0.2267 - accuracy: 0.9062 - val_loss: 0.6991 - val_accuracy: 0.7500 - 130ms/epoch - 5ms/step
# Epoch 30/100
# 25/25 - 0s - loss: 0.2208 - accuracy: 0.9038 - val_loss: 0.7267 - val_accuracy: 0.7250 - 115ms/epoch - 5ms/step
# Epoch 31/100
# 25/25 - 0s - loss: 0.2204 - accuracy: 0.8988 - val_loss: 0.7434 - val_accuracy: 0.7250 - 115ms/epoch - 5ms/step
# Epoch 32/100
# 25/25 - 0s - loss: 0.2186 - accuracy: 0.9025 - val_loss: 0.7332 - val_accuracy: 0.7400 - 117ms/epoch - 5ms/step
# Epoch 33/100
# 25/25 - 0s - loss: 0.2205 - accuracy: 0.9025 - val_loss: 0.7147 - val_accuracy: 0.7600 - 117ms/epoch - 5ms/step
# Epoch 34/100
# 25/25 - 0s - loss: 0.2173 - accuracy: 0.9075 - val_loss: 0.7693 - val_accuracy: 0.7250 - 107ms/epoch - 4ms/step
# Epoch 35/100
# 25/25 - 0s - loss: 0.2133 - accuracy: 0.9062 - val_loss: 0.7668 - val_accuracy: 0.7250 - 143ms/epoch - 6ms/step
# Epoch 36/100
# 25/25 - 0s - loss: 0.2102 - accuracy: 0.9125 - val_loss: 0.8055 - val_accuracy: 0.7200 - 125ms/epoch - 5ms/step
# Epoch 37/100
# 25/25 - 0s - loss: 0.2100 - accuracy: 0.9112 - val_loss: 0.7697 - val_accuracy: 0.7400 - 124ms/epoch - 5ms/step
# Epoch 38/100
# 25/25 - 0s - loss: 0.2162 - accuracy: 0.9062 - val_loss: 0.7752 - val_accuracy: 0.7400 - 110ms/epoch - 4ms/step
# Epoch 39/100
# 25/25 - 0s - loss: 0.2074 - accuracy: 0.9137 - val_loss: 0.8324 - val_accuracy: 0.7150 - 122ms/epoch - 5ms/step
# Epoch 40/100
# 25/25 - 0s - loss: 0.2103 - accuracy: 0.9038 - val_loss: 0.8479 - val_accuracy: 0.7100 - 115ms/epoch - 5ms/step
# Epoch 41/100
# 25/25 - 0s - loss: 0.2084 - accuracy: 0.9075 - val_loss: 0.8010 - val_accuracy: 0.7450 - 113ms/epoch - 5ms/step
# Epoch 42/100
# 25/25 - 0s - loss: 0.2028 - accuracy: 0.9125 - val_loss: 0.8597 - val_accuracy: 0.7150 - 111ms/epoch - 4ms/step
# Epoch 43/100
# 25/25 - 0s - loss: 0.2067 - accuracy: 0.9062 - val_loss: 0.8923 - val_accuracy: 0.7100 - 120ms/epoch - 5ms/step
# Epoch 44/100
# 25/25 - 0s - loss: 0.2075 - accuracy: 0.9125 - val_loss: 0.8533 - val_accuracy: 0.7100 - 114ms/epoch - 5ms/step
# Epoch 45/100
# 25/25 - 0s - loss: 0.2039 - accuracy: 0.9087 - val_loss: 0.8451 - val_accuracy: 0.7200 - 117ms/epoch - 5ms/step
# Epoch 46/100
# 25/25 - 0s - loss: 0.1983 - accuracy: 0.9100 - val_loss: 0.8757 - val_accuracy: 0.7000 - 137ms/epoch - 5ms/step
# Epoch 47/100
# 25/25 - 0s - loss: 0.1995 - accuracy: 0.9137 - val_loss: 0.8426 - val_accuracy: 0.7400 - 117ms/epoch - 5ms/step
# Epoch 48/100
# 25/25 - 0s - loss: 0.1983 - accuracy: 0.9100 - val_loss: 0.8329 - val_accuracy: 0.7400 - 118ms/epoch - 5ms/step
# Epoch 49/100
# 25/25 - 0s - loss: 0.1967 - accuracy: 0.9050 - val_loss: 0.8697 - val_accuracy: 0.7350 - 111ms/epoch - 4ms/step
# Epoch 50/100
# 25/25 - 0s - loss: 0.1946 - accuracy: 0.9175 - val_loss: 0.9049 - val_accuracy: 0.6950 - 110ms/epoch - 4ms/step
# Epoch 51/100
# 25/25 - 0s - loss: 0.1973 - accuracy: 0.9162 - val_loss: 0.8916 - val_accuracy: 0.7100 - 119ms/epoch - 5ms/step
# Epoch 52/100
# 25/25 - 0s - loss: 0.1922 - accuracy: 0.9200 - val_loss: 0.9439 - val_accuracy: 0.6950 - 118ms/epoch - 5ms/step
# Epoch 53/100
# 25/25 - 0s - loss: 0.2022 - accuracy: 0.9100 - val_loss: 0.9245 - val_accuracy: 0.7000 - 113ms/epoch - 5ms/step
# Epoch 54/100
# 25/25 - 0s - loss: 0.1905 - accuracy: 0.9175 - val_loss: 0.9019 - val_accuracy: 0.7350 - 132ms/epoch - 5ms/step
# Epoch 55/100
# 25/25 - 0s - loss: 0.1918 - accuracy: 0.9150 - val_loss: 0.9186 - val_accuracy: 0.7250 - 113ms/epoch - 5ms/step
# Epoch 56/100
# 25/25 - 0s - loss: 0.1936 - accuracy: 0.9175 - val_loss: 0.8884 - val_accuracy: 0.7350 - 115ms/epoch - 5ms/step
# Epoch 57/100
# 25/25 - 0s - loss: 0.1950 - accuracy: 0.9162 - val_loss: 0.9273 - val_accuracy: 0.7100 - 305ms/epoch - 12ms/step
# Epoch 58/100
# 25/25 - 0s - loss: 0.1898 - accuracy: 0.9212 - val_loss: 0.9339 - val_accuracy: 0.7050 - 109ms/epoch - 4ms/step
# Epoch 59/100
# 25/25 - 0s - loss: 0.1881 - accuracy: 0.9150 - val_loss: 0.9549 - val_accuracy: 0.7150 - 115ms/epoch - 5ms/step
# Epoch 60/100
# 25/25 - 0s - loss: 0.1873 - accuracy: 0.9200 - val_loss: 0.9856 - val_accuracy: 0.7000 - 116ms/epoch - 5ms/step
# Epoch 61/100
# 25/25 - 0s - loss: 0.1891 - accuracy: 0.9212 - val_loss: 1.0051 - val_accuracy: 0.6950 - 128ms/epoch - 5ms/step
# Epoch 62/100
# 25/25 - 0s - loss: 0.1890 - accuracy: 0.9225 - val_loss: 1.0358 - val_accuracy: 0.6950 - 108ms/epoch - 4ms/step
# Epoch 63/100
# 25/25 - 0s - loss: 0.1901 - accuracy: 0.9150 - val_loss: 1.0121 - val_accuracy: 0.6950 - 108ms/epoch - 4ms/step
# Epoch 64/100
# 25/25 - 0s - loss: 0.1874 - accuracy: 0.9225 - val_loss: 1.0008 - val_accuracy: 0.7100 - 115ms/epoch - 5ms/step
# Epoch 65/100
# 25/25 - 0s - loss: 0.1854 - accuracy: 0.9287 - val_loss: 1.0303 - val_accuracy: 0.6950 - 112ms/epoch - 4ms/step
# Epoch 66/100
# 25/25 - 0s - loss: 0.1934 - accuracy: 0.9287 - val_loss: 1.0164 - val_accuracy: 0.7100 - 114ms/epoch - 5ms/step
# Epoch 67/100
# 25/25 - 0s - loss: 0.1943 - accuracy: 0.9087 - val_loss: 1.0746 - val_accuracy: 0.6950 - 116ms/epoch - 5ms/step
# Epoch 68/100
# 25/25 - 0s - loss: 0.1824 - accuracy: 0.9225 - val_loss: 0.9962 - val_accuracy: 0.7250 - 117ms/epoch - 5ms/step
# Epoch 69/100
# 25/25 - 0s - loss: 0.1822 - accuracy: 0.9175 - val_loss: 1.0271 - val_accuracy: 0.7150 - 123ms/epoch - 5ms/step
# Epoch 70/100
# 25/25 - 0s - loss: 0.1814 - accuracy: 0.9275 - val_loss: 0.9941 - val_accuracy: 0.7250 - 120ms/epoch - 5ms/step
# Epoch 71/100
# 25/25 - 0s - loss: 0.1826 - accuracy: 0.9287 - val_loss: 1.0103 - val_accuracy: 0.7200 - 114ms/epoch - 5ms/step
# Epoch 72/100
# 25/25 - 0s - loss: 0.1871 - accuracy: 0.9150 - val_loss: 1.0685 - val_accuracy: 0.6950 - 116ms/epoch - 5ms/step
# Epoch 73/100
# 25/25 - 0s - loss: 0.1803 - accuracy: 0.9162 - val_loss: 1.0563 - val_accuracy: 0.7150 - 118ms/epoch - 5ms/step
# Epoch 74/100
# 25/25 - 0s - loss: 0.1787 - accuracy: 0.9225 - val_loss: 1.1155 - val_accuracy: 0.6950 - 113ms/epoch - 5ms/step
# Epoch 75/100
# 25/25 - 0s - loss: 0.1820 - accuracy: 0.9162 - val_loss: 1.1159 - val_accuracy: 0.6950 - 112ms/epoch - 4ms/step
# Epoch 76/100
# 25/25 - 0s - loss: 0.1821 - accuracy: 0.9225 - val_loss: 1.0624 - val_accuracy: 0.7150 - 124ms/epoch - 5ms/step
# Epoch 77/100
# 25/25 - 0s - loss: 0.1798 - accuracy: 0.9175 - val_loss: 1.0733 - val_accuracy: 0.7150 - 164ms/epoch - 7ms/step
# Epoch 78/100
# 25/25 - 0s - loss: 0.1753 - accuracy: 0.9212 - val_loss: 1.1047 - val_accuracy: 0.7000 - 109ms/epoch - 4ms/step
# Epoch 79/100
# 25/25 - 0s - loss: 0.1765 - accuracy: 0.9262 - val_loss: 1.1172 - val_accuracy: 0.7000 - 109ms/epoch - 4ms/step
# Epoch 80/100
# 25/25 - 0s - loss: 0.1765 - accuracy: 0.9200 - val_loss: 1.0578 - val_accuracy: 0.7200 - 111ms/epoch - 4ms/step
# Epoch 81/100
# 25/25 - 0s - loss: 0.1772 - accuracy: 0.9225 - val_loss: 1.1365 - val_accuracy: 0.7050 - 113ms/epoch - 5ms/step
# Epoch 82/100
# 25/25 - 0s - loss: 0.1865 - accuracy: 0.9262 - val_loss: 1.2463 - val_accuracy: 0.6850 - 117ms/epoch - 5ms/step
# Epoch 83/100
# 25/25 - 0s - loss: 0.1718 - accuracy: 0.9350 - val_loss: 1.0849 - val_accuracy: 0.7150 - 116ms/epoch - 5ms/step
# Epoch 84/100
# 25/25 - 0s - loss: 0.1745 - accuracy: 0.9225 - val_loss: 1.1375 - val_accuracy: 0.7050 - 114ms/epoch - 5ms/step
# Epoch 85/100
# 25/25 - 0s - loss: 0.1812 - accuracy: 0.9175 - val_loss: 1.1259 - val_accuracy: 0.7200 - 109ms/epoch - 4ms/step
# Epoch 86/100
# 25/25 - 0s - loss: 0.1754 - accuracy: 0.9287 - val_loss: 1.1347 - val_accuracy: 0.7050 - 129ms/epoch - 5ms/step
# Epoch 87/100
# 25/25 - 0s - loss: 0.1699 - accuracy: 0.9275 - val_loss: 1.1963 - val_accuracy: 0.6950 - 119ms/epoch - 5ms/step
# Epoch 88/100
# 25/25 - 0s - loss: 0.1722 - accuracy: 0.9250 - val_loss: 1.1456 - val_accuracy: 0.7150 - 112ms/epoch - 4ms/step
# Epoch 89/100
# 25/25 - 0s - loss: 0.1702 - accuracy: 0.9287 - val_loss: 1.1116 - val_accuracy: 0.7100 - 114ms/epoch - 5ms/step
# Epoch 90/100
# 25/25 - 0s - loss: 0.1736 - accuracy: 0.9275 - val_loss: 1.1743 - val_accuracy: 0.7100 - 118ms/epoch - 5ms/step
# Epoch 91/100
# 25/25 - 0s - loss: 0.1702 - accuracy: 0.9300 - val_loss: 1.1469 - val_accuracy: 0.7250 - 114ms/epoch - 5ms/step
# Epoch 92/100
# 25/25 - 0s - loss: 0.1691 - accuracy: 0.9350 - val_loss: 1.1912 - val_accuracy: 0.7150 - 115ms/epoch - 5ms/step
# Epoch 93/100
# 25/25 - 0s - loss: 0.1734 - accuracy: 0.9225 - val_loss: 1.2537 - val_accuracy: 0.7000 - 114ms/epoch - 5ms/step
# Epoch 94/100
# 25/25 - 0s - loss: 0.1801 - accuracy: 0.9312 - val_loss: 1.2570 - val_accuracy: 0.6950 - 134ms/epoch - 5ms/step
# Epoch 95/100
# 25/25 - 0s - loss: 0.1682 - accuracy: 0.9300 - val_loss: 1.2137 - val_accuracy: 0.7050 - 116ms/epoch - 5ms/step
# Epoch 96/100
# 25/25 - 0s - loss: 0.1733 - accuracy: 0.9187 - val_loss: 1.2190 - val_accuracy: 0.7000 - 115ms/epoch - 5ms/step
# Epoch 97/100
# 25/25 - 0s - loss: 0.1728 - accuracy: 0.9212 - val_loss: 1.2240 - val_accuracy: 0.7150 - 116ms/epoch - 5ms/step
# Epoch 98/100
# 25/25 - 0s - loss: 0.1656 - accuracy: 0.9250 - val_loss: 1.2436 - val_accuracy: 0.7050 - 117ms/epoch - 5ms/step
# Epoch 99/100
# 25/25 - 0s - loss: 0.1673 - accuracy: 0.9287 - val_loss: 1.2263 - val_accuracy: 0.7100 - 114ms/epoch - 5ms/step
# Epoch 100/100
# 25/25 - 0s - loss: 0.1680 - accuracy: 0.9275 - val_loss: 1.2087 - val_accuracy: 0.7200 - 113ms/epoch - 5ms/step
